# %%
import numpy as np
import pandas as pd

# %%
#1
from sklearn.impute import SimpleImputer
imputer=SimpleImputer(missing_values=np.nan,strategy="mean")
data=[[1,2],[np.nan,3],[7,6]]
imputer=imputer.fit(data)
new_data=imputer.transform(data)
print(new_data)
# Out:
# [[1. 2.]
#  [4. 3.]
#  [7. 6.]]

# %%
#2
from sklearn.preprocessing import MinMaxScaler
data=[[-1,2],[-0.5,6],[0,10],[1,18]]
scaler=MinMaxScaler()
model=scaler.fit(data)
scaled_data=model.transform(data)
print(scaled_data)
# Out:
# [[0.   0.  ]
#  [0.25 0.25]
#  [0.5  0.5 ]
#  [1.   1.  ]]

# %%
#3
file=pd.read_csv("iris .csv")

# %%
#4
file.head(4)
# Out:
#    sepallength  sepalwidth  petallength  petalwidth        class
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa

# %%
file.tail(5)
# Out:
#      sepallength  sepalwidth  petallength  petalwidth           class
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica

# %%
#5
data=pd.DataFrame(file)
print(data["sepallength"].isnull().sum())
# Out:
# 0

# %%
#6
type(data["petalwidth"])
# Out:
# pandas.core.series.Series

# %%
#7
data["petallength"].mean()
# Out:
# 3.758666666666666

# %%
#8
data["petalwidth"].std()
# Out:
# 0.7631607417008411

# %%
#9
import matplotlib.pyplot as plt
plt.hist(data["sepalwidth"])
plt.xlabel("sepalwidth")
plt.ylabel("Number of flowers")
# Out:
# Text(0, 0.5, 'Number of flowers')

# %%
plt.hist(data["petalwidth"])
plt.xlabel("petalwidth")
plt.ylabel("Number of flowers")
# Out:
# Text(0, 0.5, 'Number of flowers')

# %%
plt.hist(data["sepallength"])
plt.xlabel("sepallength")
plt.ylabel("Number of flowers")
# Out:
# Text(0, 0.5, 'Number of flowers')

# %%
plt.hist(data["petallength"])
plt.xlabel("petallength")
plt.ylabel("Number of flowers")
# Out:
# Text(0, 0.5, 'Number of flowers')

# %%
#10
import seaborn as sns
sns.scatterplot(x="petallength",y="sepalwidth",hue="class",data=data)
# Out:
# <Axes: xlabel='petallength', ylabel='sepalwidth'>

# %%
sns.scatterplot(x="sepallength",y="sepalwidth",hue="class",data=data)
# Out:
# <Axes: xlabel='sepallength', ylabel='sepalwidth'>

# %%
sns.scatterplot(x="sepallength",y="petalwidth",hue="class",data=data)
# Out:
# <Axes: xlabel='sepallength', ylabel='petalwidth'>

# %%
sns.scatterplot(x="petallength",y="petalwidth",hue="class",data=data)
# Out:
# <Axes: xlabel='petallength', ylabel='petalwidth'>
