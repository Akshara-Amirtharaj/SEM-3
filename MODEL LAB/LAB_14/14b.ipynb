# %%
import pandas as pd
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset=load_iris()

# %%
df=pd.DataFrame(data=dataset.data,columns=dataset.feature_names)

# %%
dataset.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
feature_mapping={0:'setosa',1:'versicolor',2:'virginica'}
df["species"]=pd.Series(dataset.target).map(feature_mapping)
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#        species
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ..         ...
# 145  virginica
# 146  virginica
# 147  virginica
# 148  virginica
# 149  virginica
#
# [150 rows x 5 columns]

# %%
features=dataset.feature_names

# %%
plt.figure(figsize=(8,8))
for i, feature in enumerate(features):
    
    plt.subplot(2,2,i+1)
    sns.violinplot(x="species",y=feature,data=df)
    plt.xlabel("Species")
    plt.ylabel(f"Feature:{feature}")
